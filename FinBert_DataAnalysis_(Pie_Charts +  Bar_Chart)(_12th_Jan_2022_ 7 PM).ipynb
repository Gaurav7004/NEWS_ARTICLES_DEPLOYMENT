# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurav7004/NEWS_ARTICLES_DEPLOYMENT/blob/main/FinBert_DataAnalysis_(Pie_Charts%20%2B%20%20Bar_Chart)(_12th_Jan_2022_%207%20PM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import table

# %%
df = pd.read_csv('FinBERT_Predictions.csv', encoding='utf-8')

# %%
df.head(3)
# Out:
#    Unnamed: 0  ...   Neutral
# 0           0  ...  0.026675
# 1           0  ...  0.070383
# 2           0  ...  0.902535
#
# [3 rows x 5 columns]

# %%
## Required list of keywords
# keywords =  ['GST', 'taxes', 'Stock', 'Share market', 'shares', 'GDP', 'RBI', 'Reserve Bank of India', 'inflation', 
#             'India Business', 'Indian Economy', 'Export and Import', 'Industrial output', 'EXIM', 'Profit and Loss', 
#             'Commodities prices', 'price rise', 'Loans', 'Borrowings', 'financial aid', 'mortgage', 'microfinance', 'Banking regulations', 
#             'domestic production', 'GNP', 'non industrial output', 'employment', 'unemployment', 'consumption expenditure', 'allowances', 'pay-cuts', 'recession',
#             'Forecasting', 'predictions', 'world bank', 'IMF', 'International Monetary Fund', 'Market volatility', 'Indian currency', 'exchange rates']

keywords =  ['gst', 'taxes', 'Stock','GDP', 'RBI', 'inflation', 'Loans', 'Borrowings', 'employment', 'unemployment', 'IMF']


## Lowering the string of keywords
for i in range(len(keywords)):
    keywords[i] = keywords[i].lower()

## news to list
news = df['Headline'].tolist()

## list to fill required news sentences
lst_reqdWords = []

## Extract required keywords to further count occurences
for i in range(len(keywords)):
  for j in range(len(news)):
    if keywords[i] in news[j]:
      lst_reqdWords.append(keywords[i])

## Function to count occurence of keywords
def count_keywords(lst_reqdWords, x):
    return lst_reqdWords.count(x)

## To plot most occuring word on the basis of number of counts
words = []
count_words = []
for i in range(len(keywords)):
  a = count_keywords(lst_reqdWords, keywords[i])
  if a == 0:
    pass
  else:
    count_words.append(a)
    words.append(keywords[i])
  
# # creating the bar plot
fig = plt.figure(figsize = (15, 5))
plt.title("Occurences of keywords in the news articles", bbox={'facecolor':'0.8', 'pad':5})
plt.bar(words, count_words, color ='orange', width = 0.2)
# Out:
# <BarContainer object of 11 artists>

# %%
## Separated and Total rows
len(lst_reqdWords), df.shape[0]
# Out:
# (17295, 14829)

# %%
'''
                                                                    ## ONLY for GST ##
'''

## Extract required news having 'gst' or 'GST' keyword
df_gst = df[df['Headline'].str.lower().str.contains('gst') == True]

## Dataframes having gst haing positive, negative, and neutral values
df_gst_pos = df_gst[df_gst['Positive'] >= 0.5]
df_gst_neg = df_gst[df_gst['Negative'] >= 0.5]
df_gst_neu = df_gst[df_gst['Neutral'] >= 0.5]

## Counts +ve, -ve , neutral
cnt_pos = df_gst_pos.shape[0]
cnt_neg = df_gst_neg.shape[0]
cnt_neu = df_gst.shape[0] - (cnt_pos+ cnt_neg)

print(df_gst.shape[0])
print(cnt_pos + cnt_neg  + cnt_neu)

## Raw data dictionary
raw_data = {'sentiments': ['Positive', 'Negative', 'Neutral'],
              'results': [cnt_pos, cnt_neg, cnt_neu]}

## Plot Dataframe
df_for_Plot = pd.DataFrame(raw_data, columns = ['sentiments', 'results'])

#colors = ['red', 'gold', 'yellowgreen', 'blue', 'lightcoral', 'lightskyblue']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]

# explode 1st slice
explode = (0.1, 0, 0) 

plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
df_for_Plot.plot(kind='pie', y = 'results', ax=ax1, autopct='%1.1f%%', explode=explode, colors=colors,
 startangle=90, shadow=False, labels=df_for_Plot['sentiments'], legend = False, fontsize=14)

# plot table
ax2 = plt.subplot(122)
plt.axis('off')
tbl = table(ax2, df_for_Plot, loc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(14)
plt.title("Sentiments for the keyword - gst", bbox={'facecolor':'0.8', 'pad':5})
plt.show()
# Out:
# 4355
# 4355

# %%
'''
                                                                    ## ONLY for taxes ##
'''

## Extract required news having 'taxes'' keyword
df_taxes = df[df['Headline'].str.lower().str.contains('taxes') == True]

## Dataframes having taxes haing positive, negative, and neutral values
df_taxes_pos = df_taxes[df_taxes['Positive'] >= 0.5]
df_taxes_neg = df_taxes[df_taxes['Negative'] >= 0.5]
df_taxes_neu = df_taxes[df_taxes['Neutral'] >= 0.5]

## Counts +ve, -ve , neutral
cnt_pos = df_taxes_pos.shape[0]
cnt_neg = df_taxes_neg.shape[0]
cnt_neu = df_taxes.shape[0] - (cnt_pos+ cnt_neg)

print(df_taxes.shape[0])
print(cnt_pos + cnt_neg  + cnt_neu)

## Raw data dictionary
raw_data = {'sentiments': ['Positive', 'Negative', 'Neutral'],
              'results': [cnt_pos, cnt_neg, cnt_neu]}

## Plot Dataframe
df_for_Plot = pd.DataFrame(raw_data, columns = ['sentiments', 'results'])

#colors = ['red', 'gold', 'yellowgreen', 'blue', 'lightcoral', 'lightskyblue']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]

# explode 1st slice
explode = (0.1, 0, 0) 

plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
df_for_Plot.plot(kind='pie', y = 'results', ax=ax1, autopct='%1.1f%%', explode=explode, colors=colors,
 startangle=90, shadow=False, labels=df_for_Plot['sentiments'], legend = False, fontsize=14)

# plot table
ax2 = plt.subplot(122)
plt.axis('off')
tbl = table(ax2, df_for_Plot, loc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(14)
plt.title("Sentiments for the keyword - taxes", bbox={'facecolor':'0.9', 'pad':7})
plt.show()
# Out:
# 660
# 660

# %%
'''
                                                                    ## ONLY for stock ##
'''

## Extract required news having 'stock' keyword
df_stock = df[df['Headline'].str.lower().str.contains('stock') == True]

## Dataframes having stock haing positive, negative, and neutral values
df_stock_pos = df_stock[df_stock['Positive'] >= 0.5]
df_stock_neg = df_stock[df_stock['Negative'] >= 0.5]
df_stock_neu = df_stock[df_stock['Neutral'] >= 0.5]

## Counts +ve, -ve , neutral
cnt_pos = df_stock_pos.shape[0]
cnt_neg = df_stock_neg.shape[0]
cnt_neu = df_stock.shape[0] - (cnt_pos+ cnt_neg)

print(df_stock.shape[0])
print(cnt_pos + cnt_neg  + cnt_neu)

## Raw data dictionary
raw_data = {'sentiments': ['Positive', 'Negative', 'Neutral'],
              'results': [cnt_pos, cnt_neg, cnt_neu]}

## Plot Dataframe
df_for_Plot = pd.DataFrame(raw_data, columns = ['sentiments', 'results'])

#colors = ['red', 'gold', 'yellowgreen', 'blue', 'lightcoral', 'lightskyblue']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]

# explode 1st slice
explode = (0.1, 0, 0) 

plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
df_for_Plot.plot(kind='pie', y = 'results', ax=ax1, autopct='%1.1f%%', explode=explode, colors=colors,
 startangle=90, shadow=False, labels=df_for_Plot['sentiments'], legend = False, fontsize=14)

# plot table
ax2 = plt.subplot(122)
plt.axis('off')
tbl = table(ax2, df_for_Plot, loc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(14)
plt.title("Sentiments for the keyword - stock", bbox={'facecolor':'0.9', 'pad':7})
plt.show()
# Out:
# 244
# 244

# %%
'''
                                                                    ## ONLY for gdp ##
'''

## Extract required news having 'gdp' keyword
df_gdp = df[df['Headline'].str.lower().str.contains('gdp') == True]

## Dataframes having gdp haing positive, negative, and neutral values
df_gdp_pos = df_gdp[df_gdp['Positive'] >= 0.5]
df_gdp_neg = df_gdp[df_gdp['Negative'] >= 0.5]
df_gdp_neu = df_gdp[df_gdp['Neutral'] >= 0.5]

## Counts +ve, -ve , neutral
cnt_pos = df_gdp_pos.shape[0]
cnt_neg = df_gdp_neg.shape[0]
cnt_neu = df_gdp.shape[0] - (cnt_pos+ cnt_neg)

print(df_gdp.shape[0])
print(cnt_pos + cnt_neg  + cnt_neu)

## Raw data dictionary
raw_data = {'sentiments': ['Positive', 'Negative', 'Neutral'],
              'results': [cnt_pos, cnt_neg, cnt_neu]}

## Plot Dataframe
df_for_Plot = pd.DataFrame(raw_data, columns = ['sentiments', 'results'])

#colors = ['red', 'gold', 'yellowgreen', 'blue', 'lightcoral', 'lightskyblue']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]

# explode 1st slice
explode = (0.1, 0, 0) 

plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
df_for_Plot.plot(kind='pie', y = 'results', ax=ax1, autopct='%1.1f%%', explode=explode, colors=colors,
 startangle=90, shadow=False, labels=df_for_Plot['sentiments'], legend = False, fontsize=14)

# plot table
ax2 = plt.subplot(122)
plt.axis('off')
tbl = table(ax2, df_for_Plot, loc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(14)
plt.title("Sentiments for the keyword - gdp", bbox={'facecolor':'0.8', 'pad':7})
plt.show()
# Out:
# 2071
# 2071

# %%
'''
                                                                    ## ONLY for rbi ##
'''

## Extract required news having 'rbi' keyword
df_rbi = df[df['Headline'].str.lower().str.contains('rbi') == True]

## Dataframes having rbi haing positive, negative, and neutral values
df_rbi_pos = df_rbi[df_rbi['Positive'] >= 0.5]
df_rbi_neg = df_rbi[df_rbi['Negative'] >= 0.5]
df_rbi_neu = df_rbi[df_rbi['Neutral'] >= 0.5]

## Counts +ve, -ve , neutral
cnt_pos = df_rbi_pos.shape[0]
cnt_neg = df_rbi_neg.shape[0]
cnt_neu = df_rbi.shape[0] - (cnt_pos+ cnt_neg)

print(df_rbi.shape[0])
print(cnt_pos + cnt_neg  + cnt_neu)

## Raw data dictionary
raw_data = {'sentiments': ['Positive', 'Negative', 'Neutral'],
              'results': [cnt_pos, cnt_neg, cnt_neu]}

## Plot Dataframe
df_for_Plot = pd.DataFrame(raw_data, columns = ['sentiments', 'results'])

#colors = ['red', 'gold', 'yellowgreen', 'blue', 'lightcoral', 'lightskyblue']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]

# explode 1st slice
explode = (0.1, 0, 0) 

plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
df_for_Plot.plot(kind='pie', y = 'results', ax=ax1, autopct='%1.1f%%', explode=explode, colors=colors,
 startangle=90, shadow=False, labels=df_for_Plot['sentiments'], legend = False, fontsize=14)

# plot table
ax2 = plt.subplot(122)
plt.axis('off')
tbl = table(ax2, df_for_Plot, loc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(14)
plt.title("Sentiments for the keyword - rbi", bbox={'facecolor':'0.8', 'pad':7})
plt.show()
# Out:
# 4289
# 4289

# %%
'''
                                                                    ## ONLY for inflation ##
'''

## Extract required news having 'inflation' keyword
df_inflation = df[df['Headline'].str.lower().str.contains('inflation') == True]

## Dataframes having inflation haing positive, negative, and neutral values
df_inflation_pos = df_inflation[df_inflation['Positive'] >= 0.5]
df_inflation_neg = df_inflation[df_inflation['Negative'] >= 0.5]
df_inflation_neu = df_inflation[df_inflation['Neutral'] >= 0.5]

## Counts +ve, -ve , neutral
cnt_pos = df_inflation_pos.shape[0]
cnt_neg = df_inflation_neg.shape[0]
cnt_neu = df_inflation.shape[0] - (cnt_pos+ cnt_neg)

print(df_inflation.shape[0])
print(cnt_pos + cnt_neg  + cnt_neu)

## Raw data dictionary
raw_data = {'sentiments': ['Positive', 'Negative', 'Neutral'],
              'results': [cnt_pos, cnt_neg, cnt_neu]}

## Plot Dataframe
df_for_Plot = pd.DataFrame(raw_data, columns = ['sentiments', 'results'])

#colors = ['red', 'gold', 'yellowgreen', 'blue', 'lightcoral', 'lightskyblue']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]

# explode 1st slice
explode = (0.1, 0, 0) 

plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
df_for_Plot.plot(kind='pie', y = 'results', ax=ax1, autopct='%1.1f%%', explode=explode, colors=colors,
 startangle=90, shadow=False, labels=df_for_Plot['sentiments'], legend = False, fontsize=14)

# plot table
ax2 = plt.subplot(122)
plt.axis('off')
tbl = table(ax2, df_for_Plot, loc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(14)
plt.title("Sentiments for the keyword - inflation", bbox={'facecolor':'0.8', 'pad':7})
plt.show()
# Out:
# 2579
# 2579

# %%
'''
                                                                    ## ONLY for loans ##
'''

## Extract required news having 'loans' keyword
df_loans = df[df['Headline'].str.lower().str.contains('loans') == True]

## Dataframes having loans haing positive, negative, and neutral values
df_loans_pos = df_loans[df_loans['Positive'] >= 0.5]
df_loans_neg = df_loans[df_loans['Negative'] >= 0.5]
df_loans_neu = df_loans[df_loans['Neutral'] >= 0.5]

## Counts +ve, -ve , neutral
cnt_pos = df_loans_pos.shape[0]
cnt_neg = df_loans_neg.shape[0]
cnt_neu = df_loans.shape[0] - (cnt_pos+ cnt_neg)

print(df_loans.shape[0])
print(cnt_pos + cnt_neg  + cnt_neu)

## Raw data dictionary
raw_data = {'sentiments': ['Positive', 'Negative', 'Neutral'],
              'results': [cnt_pos, cnt_neg, cnt_neu]}

## Plot Dataframe
df_for_Plot = pd.DataFrame(raw_data, columns = ['sentiments', 'results'])

#colors = ['red', 'gold', 'yellowgreen', 'blue', 'lightcoral', 'lightskyblue']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]

# explode 1st slice
explode = (0.1, 0, 0) 

plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
df_for_Plot.plot(kind='pie', y = 'results', ax=ax1, autopct='%1.1f%%', explode=explode, colors=colors,
 startangle=90, shadow=False, labels=df_for_Plot['sentiments'], legend = False, fontsize=14)

# plot table
ax2 = plt.subplot(122)
plt.axis('off')
tbl = table(ax2, df_for_Plot, loc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(14)
plt.title("Sentiments for the keyword - loans", bbox={'facecolor':'0.8', 'pad':7})
plt.show()
# Out:
# 503
# 503

# %%
'''
                                                                    ## ONLY for borrowings ##
'''

## Extract required news having 'borrowings' keyword
df_borrowings = df[df['Headline'].str.lower().str.contains('borrowings') == True]

## Dataframes having borrowings haing positive, negative, and neutral values
df_borrowings_pos = df_borrowings[df_borrowings['Positive'] >= 0.5]
df_borrowings_neg = df_borrowings[df_borrowings['Negative'] >= 0.5]
df_borrowings_neu = df_borrowings[df_borrowings['Neutral'] >= 0.5]

## Counts +ve, -ve , neutral
cnt_pos = df_borrowings_pos.shape[0]
cnt_neg = df_borrowings_neg.shape[0]
cnt_neu = df_borrowings.shape[0] - (cnt_pos+ cnt_neg)

print(df_borrowings.shape[0])
print(cnt_pos + cnt_neg  + cnt_neu)

## Raw data dictionary
raw_data = {'sentiments': ['Positive', 'Negative', 'Neutral'],
              'results': [cnt_pos, cnt_neg, cnt_neu],
                }

## Plot Dataframe
df_for_Plot = pd.DataFrame(raw_data, columns = ['sentiments', 'results'])

#colors = ['red', 'gold', 'yellowgreen', 'blue', 'lightcoral', 'lightskyblue']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]

# explode 1st slice
explode = (0.1, 0, 0) 

plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
df_for_Plot.plot(kind='pie', y = 'results', ax=ax1, autopct='%1.1f%%', explode=explode, colors=colors,
 startangle=90, shadow=False, labels=df_for_Plot['sentiments'], legend = False, fontsize=14)

# plot table
ax2 = plt.subplot(122)
plt.axis('off')
tbl = table(ax2, df_for_Plot, loc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(14)
plt.title("Sentiments for the keyword - borrowings", bbox={'facecolor':'0.8', 'pad':7})
plt.show()
# Out:
# 213
# 213

# %%
'''
                                                                    ## ONLY for employment ##
'''

## Extract required news having 'employment' keyword
df_employment = df[df['Headline'].str.lower().str.contains('employment') == True]

## Dataframes having employment haing positive, negative, and neutral values
df_employment_pos = df_employment[df_employment['Positive'] >= 0.5]
df_employment_neg = df_employment[df_employment['Negative'] >= 0.5]
df_employment_neu = df_employment[df_employment['Neutral'] >= 0.5]

## Counts +ve, -ve , neutral
cnt_pos = df_employment_pos.shape[0]
cnt_neg = df_employment_neg.shape[0]
cnt_neu = df_employment.shape[0] - (cnt_pos+ cnt_neg)

print(df_employment.shape[0])
print(cnt_pos + cnt_neg  + cnt_neu)

## Raw data dictionary
raw_data = {'sentiments': ['Positive', 'Negative', 'Neutral'],
              'results': [cnt_pos, cnt_neg, cnt_neu],
                }

## Plot Dataframe
df_for_Plot = pd.DataFrame(raw_data, columns = ['sentiments', 'results'])

#colors = ['red', 'gold', 'yellowgreen', 'blue', 'lightcoral', 'lightskyblue']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]

# explode 1st slice
explode = (0.1, 0, 0) 

plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
df_for_Plot.plot(kind='pie', y = 'results', ax=ax1, autopct='%1.1f%%', explode=explode, colors=colors,
 startangle=90, shadow=False, labels=df_for_Plot['sentiments'], legend = False, fontsize=14)

# plot table
ax2 = plt.subplot(122)
plt.axis('off')
tbl = table(ax2, df_for_Plot, loc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(14)
plt.title("Sentiments for the keyword - employment", bbox={'facecolor':'0.8', 'pad':7})
plt.show()
# Out:
# 1046
# 1046

# %%
'''
                                                                    ## ONLY for unemployment ##
'''

## Extract required news having 'unemployment' keyword
df_unemployment = df[df['Headline'].str.lower().str.contains('unemployment') == True]

## Dataframes having unemployment haing positive, negative, and neutral values
df_unemployment_pos = df_unemployment[df_unemployment['Positive'] >= 0.5]
df_unemployment_neg = df_unemployment[df_unemployment['Negative'] >= 0.5]
df_unemployment_neu = df_unemployment[df_unemployment['Neutral'] >= 0.5]

## Counts +ve, -ve , neutral
cnt_pos = df_unemployment_pos.shape[0]
cnt_neg = df_unemployment_neg.shape[0]
cnt_neu = df_unemployment.shape[0] - (cnt_pos+ cnt_neg)

print(df_unemployment.shape[0])
print(cnt_pos + cnt_neg  + cnt_neu)

## Raw data dictionary
raw_data = {'sentiments': ['Positive', 'Negative', 'Neutral'],
              'results': [cnt_pos, cnt_neg, cnt_neu],
                }

## Plot Dataframe
df_for_Plot = pd.DataFrame(raw_data, columns = ['sentiments', 'results'])

#colors = ['red', 'gold', 'yellowgreen', 'blue', 'lightcoral', 'lightskyblue']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]

# explode 1st slice
explode = (0.1, 0, 0) 

plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
df_for_Plot.plot(kind='pie', y = 'results', ax=ax1, autopct='%1.1f%%', explode=explode, colors=colors,
 startangle=90, shadow=False, labels=df_for_Plot['sentiments'], legend = False, fontsize=14)

# plot table
ax2 = plt.subplot(122)
plt.axis('off')
tbl = table(ax2, df_for_Plot, loc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(14)
plt.title("Sentiments for the keyword - unemployment", bbox={'facecolor':'0.8', 'pad':7})
plt.show()
# Out:
# 368
# 368

# %%
'''
                                                                    ## ONLY for imf ##
'''

## Extract required news having 'imf' keyword
df_imf = df[df['Headline'].str.lower().str.contains('imf') == True]

## Dataframes having imf haing positive, negative, and neutral values
df_imf_pos = df_imf[df_imf['Positive'] >= 0.5]
df_imf_neg = df_imf[df_imf['Negative'] >= 0.5]
df_imf_neu = df_imf[df_imf['Neutral'] >= 0.5]

## Counts +ve, -ve , neutral
cnt_pos = df_imf_pos.shape[0]
cnt_neg = df_imf_neg.shape[0]
cnt_neu = df_imf.shape[0] - (cnt_pos+ cnt_neg)

print(df_imf.shape[0])
print(cnt_pos + cnt_neg  + cnt_neu)

## Raw data dictionary
raw_data = {'sentiments': ['Positive', 'Negative', 'Neutral'],
              'results': [cnt_pos, cnt_neg, cnt_neu],
                }

## Plot Dataframe
df_for_Plot = pd.DataFrame(raw_data, columns = ['sentiments', 'results'])

#colors = ['red', 'gold', 'yellowgreen', 'blue', 'lightcoral', 'lightskyblue']
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]

# explode 1st slice
explode = (0.1, 0, 0) 

plt.figure(figsize=(16,8))
# plot chart
ax1 = plt.subplot(121, aspect='equal')
df_for_Plot.plot(kind='pie', y = 'results', ax=ax1, autopct='%1.1f%%', explode=explode, colors=colors,
 startangle=70, shadow=False, labels=df_for_Plot['sentiments'], legend = False, fontsize=14)

# plot table
ax2 = plt.subplot(122)
plt.axis('off')
tbl = table(ax2, df_for_Plot, loc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(14)
plt.title("Sentiments for the keyword - imf", bbox={'facecolor':'0.8', 'pad':7})
plt.show()
# Out:
# 302
# 302
